# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pit

# %%
salaryData = pd.read_csv("Salaries - Salaries.csv")

# %%
top5 = salaryData.head(10)

# %%
top5
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year
# 0  167411.18         0.00  400184.25  567595.43         567595.43  2011
# ...

# %%
salaryData.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# ...

# %%
top5.loc(':', 'TotalPay')
top5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 top5.loc(':', 'TotalPay')
#       2 top5
#
# TypeError: _LocationIndexer.__call__() takes from 1 to 2 positional arguments but 3 were given

# %%
npArrr = np.arange(1,11)
npArrr2 = npArrr*npArrr +2
npArrr2
# Out:
# array([  3,   6,  11,  18,  27,  38,  51,  66,  83, 102])

# %%
pit.plot(npArrr, npArrr2)

# %%
pit.scatter(npArrr2,npArrr)
pit.savefig('scatter.png')

# %%
pit.savefig('scatter.png')

# %%
plt = pit

# %%
plt.plot(npArrr, npArrr2, 'y')

# %%
plt.subplot(2,1,1)
plt.plot(npArrr, npArrr2)
plt.subplot(2,1,2)
plt.plot(npArrr, npArrr2)

# %%
plt.subplot(2,3,5)
plt.plot(npArrr,npArrr2)
plt.plot(npArrr,npArrr2)

# %%
x = np.arange(1,11)
y = x**3 +2
plt.title('hello')
plt.xlabel('xasix')
plt.ylabel('yaxis')
plt.plot(x,y)

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\lenovo\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
x = np.arange(0,5,.1)
y = np.sin(x)
y
plt.plot(x, y)

# %%
x = np.arange(0,5,.1)
y = np.cos(x)
y
fig, ax = plt.subplots()

plt.plot(x, y)

# %%
plt.bar(['gaye', 'gain'], [22,32])
# Out:
# <BarContainer object of 2 artists>
