# %%
# !pip install numpy pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
df = pd.read_csv('Salaries - Salaries.csv')
print(df.loc[df["TotalPay"] > 300000 , 'EmployeeName'] )
print(df.describe())

df.head().to_csv('topFive.csv')
df.describe().to_csv('described.csv')
# Out:
# 0             NATHANIEL FORD
# 1               GARY JIMENEZ
# 2             ALBERT PARDINI
# 3          CHRISTOPHER CHONG
# 4            PATRICK GARDNER
#                  ...
# 110540      David L Franklin
# 110542           Yifang Qian
# 110543     Richard L Corriea
# 110545           Jose L Velo
# 110546    Bryan W Rubenstein
# Name: EmployeeName, Length: 61, dtype: str
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
# ...

# %%
df['BasePay'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650     True
# 148651     True
# 148652     True
# 148653    False
# Name: BasePay, Length: 148654, dtype: bool

# %%
df.iloc[df['EmployeeName'] == '']
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, TotalPay, TotalPayBenefits, Year]
# Index: []

# %%
print(df.iloc[df['EmployeeName'] == 'NATHANIEL FORD'])
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year
# 0  167411.18          0.0  400184.25  567595.43         567595.43  2011

# %%
df.iloc[df['EmployeeName'] == 'NATHANIEL FORD']
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year
# 0  167411.18          0.0  400184.25  567595.43         567595.43  2011
